# %%
import pandas as pd
dataSet1 = [1,3,5,7]
dataSet2 = [2,4,6,8,10]
series1 = pd.Series(dataSet1)
series2 = pd.Series(dataSet2)
series3 = series1+series2;
#print("pandas Series1:");
print(series3);
# Out:
# 0     3.0
# 1     7.0
# 2    11.0
# 3    15.0
# 4     NaN
# dtype: float64

# %%
data={'apple':[1,2,3,4],'orange':[5,6,7,8]}
purchase = pd.DataFrame(data)
purchase
# Out:
#    apple  orange
# 0      1       5
# 1      2       6
# 2      3       7
# 3      4       8

# %%
purchases = pd.DataFrame(data, index=['June','Robert','Lily','David'])
purchases
# Out:
#         apple  orange
# June        1       5
# Robert      2       6
# Lily        3       7
# David       4       8

# %%
purchases.loc['June']
# Out:
# apple     1
# orange    5
# Name: June, dtype: int64

# %%
import pandas as pd
matches_df1 = pd.read_csv("CustomerLoyaltyProgram.csv")
matches_df1
# Out:
#        Loyalty# First Name    Last Name         Customer Name         Country  \
# 0      837810.0    Abigail        Goris         Abigail Goris          Canada
# 1      707928.0        Ada       Glaude            Ada Glaude         Germany
# 2      901442.0        Ada      Staback           Ada Staback          Canada
# 3      237303.0       Adam        Boner            Adam Boner          Canada
# 4      348835.0       Adam     Dunnegan         Adam Dunnegan          Canada
# 5      186842.0   Adelaide        Drago        Adelaide Drago         Germany
# 6      605640.0      Adell       Maroni          Adell Maroni  United Kingdom
# 7      723924.0     Adolph         Prey           Adolph Prey         Germany
# 8      202299.0      Adria   Osterstuck      Adria Osterstuck          Canada
# 9      826271.0    Adriane       Dottin        Adriane Dottin          Canada
# 10     616030.0     Akilah    Caravalho      Akilah Caravalho         Germany
# ...

# %%
import pandas as pd
clp_df1 = pd.read_csv("CustomerLoyaltyProgram.csv", index_col="LoyaltyStatus")
clp_df1
# Out:
#                Loyalty# First Name    Last Name         Customer Name  \
# LoyaltyStatus
# Bronze         837810.0    Abigail        Goris         Abigail Goris
# Bronze         707928.0        Ada       Glaude            Ada Glaude
# Bronze         901442.0        Ada      Staback           Ada Staback
# Bronze         237303.0       Adam        Boner            Adam Boner
# Bronze         348835.0       Adam     Dunnegan         Adam Dunnegan
# Bronze         186842.0   Adelaide        Drago        Adelaide Drago
# Elite          605640.0      Adell       Maroni          Adell Maroni
# Bronze         723924.0     Adolph         Prey           Adolph Prey
# Elite          202299.0      Adria   Osterstuck      Adria Osterstuck
# Bronze         826271.0    Adriane       Dottin        Adriane Dottin
# Bronze         616030.0     Akilah    Caravalho      Akilah Caravalho
# Bronze         747903.0         Al       Johson             Al Johson
# ...

# %%
matches_df1.head(10)
# Out:
#    Loyalty# First Name   Last Name     Customer Name         Country  \
# 0  837810.0    Abigail       Goris     Abigail Goris          Canada
# 1  707928.0        Ada      Glaude        Ada Glaude         Germany
# 2  901442.0        Ada     Staback       Ada Staback          Canada
# 3  237303.0       Adam       Boner        Adam Boner          Canada
# 4  348835.0       Adam    Dunnegan     Adam Dunnegan          Canada
# 5  186842.0   Adelaide       Drago    Adelaide Drago         Germany
# 6  605640.0      Adell      Maroni      Adell Maroni  United Kingdom
# 7  723924.0     Adolph        Prey       Adolph Prey         Germany
# 8  202299.0      Adria  Osterstuck  Adria Osterstuck          Canada
# 9  826271.0    Adriane      Dottin    Adriane Dottin          Canada
#
#   Province or State          City   Latitude   Longitude Postal code  ...  \
# 0  British Columbia  Dawson Creek  55.759627 -120.237662     U5I 4F1  ...
# ...

# %%
matches_df1.tail(3)
# Out:
#        Loyalty# First Name Last Name     Customer Name         Country  \
# 89947  100339.0      Zenia   Weidert     Zenia Weidert  United Kingdom
# 89948  220548.0    Zenobia  Marlette  Zenobia Marlette   United States
# 89949  949511.0       Zina    Kocsis       Zina Kocsis   United States
#
#       Province or State              City   Latitude   Longitude Postal code  \
# 89947           Reading       Ilkley Road  51.474026   -0.987402     RG4 7BD
# 89948        California       Los Angeles  34.052234 -118.243685       90101
# 89949          Colorado  Colorado Springs  38.833882 -104.821363       80925
#
#        ... LoyaltyStatus Product Line Coupon Response  Count Quantity Sold  \
# 89947  ...         Elite  Photography        Coupon 4    1.0           1.0
# 89948  ...         Elite  Photography        Coupon 1    1.0           2.0
# 89949  ...        Silver  Photography        Coupon 4    1.0           1.0
#
# ...

# %%
matches_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89950 entries, 0 to 89949
# Data columns (total 28 columns):
# Loyalty#                   84445 non-null float64
# First Name                 84445 non-null object
# Last Name                  84445 non-null object
# Customer Name              84445 non-null object
# Country                    84445 non-null object
# Province or State          84445 non-null object
# City                       84445 non-null object
# Latitude                   84436 non-null float64
# Longitude                  84436 non-null float64
# Postal code                84445 non-null object
# Gender                     84445 non-null object
# Education                  84445 non-null object
# Location Code              84445 non-null object
# Income                     84445 non-null float64
# Marital Status             84445 non-null object
# Order Year                 84445 non-null float64
# Quarter                    84445 non-null object
# ...

# %%
matches_df1.shape
# Out:
# (89950, 28)

# %%
temp_df = matches_df1.append(matches_df1)

print(temp_df.shape)

temp_df = temp_df.drop_duplicates()

temp_df.shape
# Out:
# (179900, 28)
# (84446, 28)

# %%
soup = BeautifulSoup(data.text, "html.parser")

# %%
# Step 1: Importing libraries
from bs4 import BeautifulSoup
import requests

# %%
# Step 2: Adding URL
link = "https://ravindrababuravula.com/courses.php"
data = requests.get(link)

# %%
# Step 3: Creating Soup object
soup = BeautifulSoup(data.text, "html.parser")

# %%
for i in soup.find_all('a', class_="title") : 
  print(i.text)
# Out:
# GATE
# Job Interview Preparation
# Technologies

# %%
for i in soup.find_all('a', class_="title") : 
  print(i.text)
# Out:
# GATE
# Job Interview Preparation
# Technologies

# %%
for i in soup.find_all('div', class_="description") : 
  print(i.text)
# Out:
# Every subject is taught from scratch and contains concepts, solved examples, important previous year GATE questions, practice questions and the test series
# It is a mix of theory and practice. we will explain all the possible ways to solve a problem and analyse each solution using Time & Space Complexity.
# We chose the Trending Technologies which are high in demand in the job market. Hybrid teaching style with the help of conventional white board and the digital screen for easy understanding.
